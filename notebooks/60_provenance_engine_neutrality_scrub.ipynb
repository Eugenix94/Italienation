# %% [markdown]
# # Notebook 60: The Provenance Engine & Neutrality Scrub
#
# This notebook executes a deep-cleaning operation across the entire dataset:
# 1. Replaces all interpretive terminology with strict empirical descriptors.
# 2. Embeds exact, verifiable source URLs (Eurostat table codes, OECD databases, national registries) into every terminal node of the global scorecard and blind spots ontology.
