# %% [markdown]
# # Notebook 59: The Global Benchmark Scorecard
#
# This notebook establishes a highly trustful, clear, holistic, and completed view of Italy's status by comparing its structural metrics against international benchmarks across 5 pillars: Macro-Fiscal, Educational, Labor, Demographics, and Socio-Territorial.

# %%
import json
from pathlib import Path

ROOT = Path('c:/Users/Dell/Documents/Antigravity/Italienation').resolve()
PROC = ROOT / 'local_data/processed'

scorecard = {
    "Pillar_1_Macro_Fiscal": {
        "Metric_Public_Debt_to_GDP": {
            "Italy": "137.3%",
            "EU_Average": "81.9%",
            "Benchmark_Leader": "Estonia (19.6%)",
            "Delta": "+55.4% vs EU",
            "Source": "Eurostat (2023)"
        },
        "Metric_Tax_Wedge": {
            "Italy": "45.9%",
            "OECD_Average": "34.8%",
            "Benchmark_Leader": "Switzerland (23.4%)",
            "Delta": "+11.1% vs OECD",
            "Source": "OECD Taxing Wages (2023)"
        },
        "Metric_Shadow_Economy_Size": {
            "Italy": "~10.5%",
            "EU_Average": "~7.0%",
            "Benchmark_Leader": "Netherlands (~3.0%)",
            "Delta": "+3.5% vs EU",
            "Source": "ISTAT / IMF"
        }
    },
    "Pillar_2_Educational_Pipeline": {
        "Metric_Age_of_First_Tracking": {
            "Italy": "13-14",
            "OECD_Average": "15",
            "Benchmark_Leader": "Finland/Canada (16+ Comprehensive)",
            "Delta": "-2 years (Early Calcification)",
            "Source": "Eurydice"
        },
        "Metric_Early_School_Leaving_Dropouts": {
            "Italy": "10.5%",
            "EU_Average": "9.5%",
            "Benchmark_Leader": "Croatia (2.0%)",
            "Delta": "+1.0% vs EU",
            "Source": "Eurostat"
        },
        "Metric_PISA_Math_Score": {
            "Italy": "471",
            "OECD_Average": "472",
            "Benchmark_Leader": "Singapore (575) / Estonia (510)",
            "Delta": "-1 vs OECD (Huge North/South variance hidden in average)",
            "Source": "OECD PISA 2022"
        }
    },
    "Pillar_3_Labor_and_Exploitation": {
        "Metric_NEET_Rate_15_29_years": {
            "Italy": "16.1%",
            "EU_Average": "11.2%",
            "Benchmark_Leader": "Netherlands (4.2%)",
            "Delta": "+4.9% vs EU",
            "Source": "Eurostat (2023)"
        },
        "Metric_Youth_Unemployment_15_24": {
            "Italy": "22.7%",
            "EU_Average": "14.9%",
            "Benchmark_Leader": "Germany (5.8%)",
            "Delta": "+7.8% vs EU",
            "Source": "Eurostat (2023)"
        },
        "Metric_Apprenticeship_Wage": {
            "Italy": "€0 (Unpaid PCTO)",
            "Benchmark": "Paid Minimum Wage",
            "Benchmark_Leader": "Germany (Dual System, min €649/month 1st year)",
            "Delta": "Structural Subsidy of Free Labor",
            "Source": "MIM / BIBB"
        }
    },
    "Pillar_4_Demographics": {
        "Metric_Birth_Rate_Per_Woman": {
            "Italy": "1.20",
            "EU_Average": "1.46",
            "Benchmark_Leader": "France (1.79)",
            "Delta": "-0.26 vs EU (Demographic Collapse)",
            "Source": "Eurostat"
        },
        "Metric_Brain_Drain_Tertiary_Graduates_Leaving": {
            "Italy": "High (Net Negative)",
            "EU_Average": "Balanced",
            "Benchmark_Leader": "Switzerland (Net Positive Intake)",
            "Delta": "Massive human capital flight",
            "Source": "ISTAT / World Bank"
        }
    },
    "Pillar_5_Socio_Territorial": {
        "Metric_Gini_Index_Wealth_Inequality": {
            "Italy": "32.7",
            "EU_Average": "29.6",
            "Benchmark_Leader": "Slovakia (21.2)",
            "Delta": "+3.1 vs EU",
            "Source": "Eurostat"
        },
        "Metric_Corruption_Perception_Index": {
            "Italy": "56/100",
            "EU_Average": "64/100",
            "Benchmark_Leader": "Denmark (90/100)",
            "Delta": "-8 points (Higher Corruption/Crime proxy)",
            "Source": "Transparency International 2023"
        }
    }
}

out_path = PROC / 'italy_vs_world_scorecard.json'
with open(out_path, 'w', encoding='utf-8') as f:
    json.dump(scorecard, f, ensure_ascii=False, indent=2)

print(f"Global Benchmark Scorecard generated at {out_path}")

# Prepend this to the master ontology to provide the Ultimate Global Context
master_path = PROC / 'italy_systemic_ontology.json'
with open(master_path, 'r', encoding='utf-8') as f:
    master = json.load(f)

# Rebuild the dictionary with Scorecard as the very first contextual layer
new_master = {
    "Italy_Systemic_Ontology": {
        "Level_Minus_1_Global_Context_Scorecard": scorecard
    }
}

# Copy the rest
for key, value in master['Italy_Systemic_Ontology'].items():
    new_master['Italy_Systemic_Ontology'][key] = value

with open(master_path, 'w', encoding='utf-8') as f:
    json.dump(new_master, f, ensure_ascii=False, indent=2)

print("Master Ontology updated with Global Context Scorecard.")
# Out:
# Global Benchmark Scorecard generated at C:\Users\Dell\Documents\Antigravity\Italienation\local_data\processed\italy_vs_world_scorecard.json
# Master Ontology updated with Global Context Scorecard.
